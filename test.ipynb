# %%
import urllib.request
from bs4 import BeautifulSoup

# %%
url = 'https://finance.naver.com/'

# %%
response = urllib.request.urlopen(url)

# %%
html = response.read()

# %%
print(type(html))
print(html)
# Out:
# <class 'bytes'>
# ...

# %%
soup = BeautifulSoup(html.decode('euc-kr', 'replace'), 'html.parser')
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
title_links = soup.findAll('h1')
print(title_links)
# Out:
# [<h1 class="logo"> <a class="logo_naver" href="https://www.naver.com/" onclick="clickcr(this, 'STA.naver', '', '', event);"><span class="blind">네이버</span></a> <a class="logo_service" href="/" onclick="clickcr(this, 'STA.finance', '', '', event);"><span class="blind">금융</span></a> </h1>]

# %%
articles = {}
for link in title_links:
    if link.a:
        print(link.a)
        articles[link.a['href']] = link.text.strip()
print(articles)
for article in articles:
    print(f'{articles[article]} - {article}')
# Out:
# <a class="logo_naver" href="https://www.naver.com/" onclick="clickcr(this, 'STA.naver', '', '', event);"><span class="blind">네이버</span></a>
# {'https://www.naver.com/': '네이버 금융'}
# 네이버 금융 - https://www.naver.com/

# %%
url = 'https://opendart.fss.or.kr/api/company.xml?crtfc_key=336d2dad4c37d6904db39122122510942dc9de6a&corp_code=00260985'
stock_list = ['00126380']

# %%
response = urllib.request.urlopen(url)

# %%
html = response.read()

# %%
soup = BeautifulSoup(html.decode('utf-8', 'replace'), 'html.parser')

# %%
print(soup)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><result><status>000</status><message>정상</message><corp_code>00260985</corp_code><corp_name>한빛네트</corp_name><corp_name_eng>HanbitNet, Inc.</corp_name_eng><stock_name>한빛네트</stock_name><stock_code>036720</stock_code><ceo_nm>강승환</ceo_nm><corp_cls>E</corp_cls><jurir_no>1101111443079</jurir_no><bizr_no>2088124283</bizr_no><adres>서울특별시 종로구 익선동 30-6</adres><hm_url>www.hanbitnet.com</hm_url><ir_url></ir_url><phn_no>02-3668-0114</phn_no><fax_no>02-3668-0112</fax_no><induty_code>58221</induty_code><est_dt>19970722</est_dt><acc_mt>12</acc_mt></result>
